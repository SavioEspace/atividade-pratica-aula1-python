# %% [markdown]
# # Aula 5 - Visualização

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('vendas_brasil_clean_aula5.csv')

# %%
df.groupby('uf')['receita'].sum().plot(kind='bar')
plt.show()

# %% [markdown]
# Gráfico mostra receita por estado.
